# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import seaborn as sns
from sklearn import svm, datasets
from sklearn.inspection import DecisionBoundaryDisplay
from sklearn.model_selection import GridSearchCV
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score, mean_squared_error, precision_score, recall_score, confusion_matrix, f1_score
from sklearn.metrics import classification_report, ConfusionMatrixDisplay
from scipy import stats
from sklearn.preprocessing import StandardScaler
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_13476\3118869573.py in <module>
#       4 import seaborn as sns
#       5 from sklearn import svm, datasets
# ----> 6 from sklearn.inspection import DecisionBoundaryDisplay
#       7 from sklearn.model_selection import GridSearchCV
#       8 from sklearn.model_selection import train_test_split
#
# ImportError: cannot import name 'DecisionBoundaryDisplay' from 'sklearn.inspection' (C:\Users\USER\anaconda3\lib\site-packages\sklearn\inspection\__init__.py)

# %% [markdown]
# Importation de données

# %%
iris = datasets.load_iris()

# Creation du dataframe
df = pd.DataFrame(iris.data, columns = iris.feature_names)
df['target'] = iris.target
df

# %% [markdown]
# Selection de features

# %%
plt.figure(1)
sns.heatmap(df.corr(), annot= True)
plt.title('Correlation sur les données')
# Out:
# Text(0.5, 1.0, 'Correlation sur les données')

# %%
X = np.array(df.loc[:, ["sepal length (cm)","sepal width (cm)"] ])
y = iris.target
X_train, X_test, Y_train, Y_test = train_test_split(X, y, test_size=0.2, random_state =5 )
print(X)
# Out:
# [[5.1 3.5]
#  [4.9 3. ]
#  [4.7 3.2]
#  [4.6 3.1]
#  [5.  3.6]
#  [5.4 3.9]
#  [4.6 3.4]
#  [5.  3.4]
#  [4.4 2.9]
#  [4.9 3.1]
#  [5.4 3.7]
#  [4.8 3.4]
#  [4.8 3. ]
#  [4.3 3. ]
#  [5.8 4. ]
#  [5.7 4.4]
#  [5.4 3.9]
#  [5.1 3.5]
#  [5.7 3.8]
#  [5.1 3.8]
#  [5.4 3.4]
#  [5.1 3.7]
#  [4.6 3.6]
#  [5.1 3.3]
#  [4.8 3.4]
#  [5.  3. ]
#  [5.  3.4]
#  [5.2 3.5]
#  [5.2 3.4]
#  [4.7 3.2]
#  [4.8 3.1]
#  [5.4 3.4]
#  [5.2 4.1]
#  [5.5 4.2]
#  [4.9 3.1]
#  [5.  3.2]
#  [5.5 3.5]
#  [4.9 3.6]
#  [4.4 3. ]
#  [5.1 3.4]
#  [5.  3.5]
#  [4.5 2.3]
#  [4.4 3.2]
#  [5.  3.5]
#  [5.1 3.8]
#  [4.8 3. ]
#  [5.1 3.8]
#  [4.6 3.2]
#  [5.3 3.7]
#  [5.  3.3]
#  [7.  3.2]
#  [6.4 3.2]
#  [6.9 3.1]
#  [5.5 2.3]
#  [6.5 2.8]
#  [5.7 2.8]
#  [6.3 3.3]
#  [4.9 2.4]
#  [6.6 2.9]
#  [5.2 2.7]
#  [5.  2. ]
#  [5.9 3. ]
#  [6.  2.2]
#  [6.1 2.9]
#  [5.6 2.9]
#  [6.7 3.1]
#  [5.6 3. ]
#  [5.8 2.7]
#  [6.2 2.2]
#  [5.6 2.5]
#  [5.9 3.2]
#  [6.1 2.8]
#  [6.3 2.5]
#  [6.1 2.8]
#  [6.4 2.9]
#  [6.6 3. ]
#  [6.8 2.8]
#  [6.7 3. ]
#  [6.  2.9]
#  [5.7 2.6]
#  [5.5 2.4]
#  [5.5 2.4]
#  [5.8 2.7]
#  [6.  2.7]
#  [5.4 3. ]
#  [6.  3.4]
#  [6.7 3.1]
#  [6.3 2.3]
#  [5.6 3. ]
#  [5.5 2.5]
#  [5.5 2.6]
#  [6.1 3. ]
#  [5.8 2.6]
#  [5.  2.3]
#  [5.6 2.7]
#  [5.7 3. ]
#  [5.7 2.9]
#  [6.2 2.9]
#  [5.1 2.5]
#  [5.7 2.8]
#  [6.3 3.3]
#  [5.8 2.7]
#  [7.1 3. ]
#  [6.3 2.9]
#  [6.5 3. ]
#  [7.6 3. ]
#  [4.9 2.5]
#  [7.3 2.9]
#  [6.7 2.5]
#  [7.2 3.6]
#  [6.5 3.2]
#  [6.4 2.7]
#  [6.8 3. ]
#  [5.7 2.5]
#  [5.8 2.8]
#  [6.4 3.2]
#  [6.5 3. ]
#  [7.7 3.8]
#  [7.7 2.6]
#  [6.  2.2]
#  [6.9 3.2]
#  [5.6 2.8]
#  [7.7 2.8]
#  [6.3 2.7]
#  [6.7 3.3]
#  [7.2 3.2]
#  [6.2 2.8]
#  [6.1 3. ]
#  [6.4 2.8]
#  [7.2 3. ]
#  [7.4 2.8]
#  [7.9 3.8]
#  [6.4 2.8]
#  [6.3 2.8]
#  [6.1 2.6]
#  [7.7 3. ]
#  [6.3 3.4]
#  [6.4 3.1]
#  [6.  3. ]
#  [6.9 3.1]
#  [6.7 3.1]
#  [6.9 3.1]
#  [5.8 2.7]
#  [6.8 3.2]
#  [6.7 3.3]
#  [6.7 3. ]
#  [6.3 2.5]
#  [6.5 3. ]
#  [6.2 3.4]
#  [5.9 3. ]]

# %%
#visualisation des données
plt.figure(figsize=(10, 6))
plt.scatter(X[y == 0][:, 0], X[y == 0][:, 1], color='g', label='0')
plt.scatter(X[y == 1][:, 0], X[y == 1][:, 1], color='y', label='1')
plt.scatter(X[y == 2][:, 0], X[y == 2][:, 1], color='r', label='2')
plt.xlabel("Longueur (cm)")
plt.ylabel("Largeur (cm)")
plt.title("Les 3 catégories de fleurs d'IRIS ")
plt.legend();

# %%
df.isnull().sum()
# Out:
# sepal length (cm)    0
# sepal width (cm)     0
# petal length (cm)    0
# petal width (cm)     0
# target               0
# dtype: int64

# %%
df.dtypes
# Out:
# sepal length (cm)    float64
# sepal width (cm)     float64
# petal length (cm)    float64
# petal width (cm)     float64
# target                 int32
# dtype: object

# %%
df.describe()
# Out:
#        sepal length (cm)  sepal width (cm)  petal length (cm)  \
# count         150.000000        150.000000         150.000000
# mean            5.843333          3.057333           3.758000
# std             0.828066          0.435866           1.765298
# min             4.300000          2.000000           1.000000
# 25%             5.100000          2.800000           1.600000
# 50%             5.800000          3.000000           4.350000
# 75%             6.400000          3.300000           5.100000
# max             7.900000          4.400000           6.900000
#
#        petal width (cm)      target
# count        150.000000  150.000000
# mean           1.199333    1.000000
# std            0.762238    0.819232
# min            0.100000    0.000000
# 25%            0.300000    0.000000
# 50%            1.300000    1.000000
# 75%            1.800000    2.000000
# max            2.500000    2.000000

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 5 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   sepal length (cm)  150 non-null    float64
#  1   sepal width (cm)   150 non-null    float64
#  2   petal length (cm)  150 non-null    float64
#  3   petal width (cm)   150 non-null    float64
#  4   target             150 non-null    int32
# dtypes: float64(4), int32(1)
# memory usage: 5.4 KB

# %%
pearson_coef, p_value = stats.pearsonr(df['sepal length (cm)'], df['sepal width (cm)'])
print( "The Pearson Correlation Coefficient is", pearson_coef, " with a P-value of P = ", p_value )
# Out:
# The Pearson Correlation Coefficient is -0.11756978413300209  with a P-value of P =  0.15189826071143123

# %% [markdown]
# Developpement et Conception du Modèle

# %%
def classificationCase(C, g):
    models = (
    svm.SVC(kernel="linear", C=C),
    svm.LinearSVC(C=C, max_iter=100000),
    svm.SVC(kernel="rbf", gamma=g, C=C),
    svm.SVC(kernel="poly", degree=3, gamma=g, C=C),
    )
    return models

def regressionCase(C,g):
    models = (
    svm.SVR(kernel="linear", C=C),
    svm.LinearSVR(C=C, max_iter=100000),
    svm.SVR(kernel="rbf", gamma=g, C=C),
    svm.SVR(kernel="poly", degree=3, gamma=g, C=C),
    )
    return models

# %%
# nous créons une instance de SVM et aménageons les données. Nous ne dimensionnons pas notre
# données puisque nous voulons tracer les vecteurs de support
# Recherche par l'agorithme de Tuning du paramètre de regularisation SVM

choice = int(input("Tapez 1 si vous voulez faire de la classification ou 2 si la regression\n"))

param_grid = {'C': [0.1, 1, 3, 10], 'gamma': [1, 0.1, 0.7, 0.01 ]}
grid = GridSearchCV(svm.SVC(),param_grid, refit=True,verbose=3)  # 
grid.fit(X_train, Y_train)
C = grid.best_estimator_.C
g = grid.best_estimator_.gamma
print(grid)

if(choice==1):
    models = classificationCase(C, g)
else:
    models = regressionCase(C, g)

# titre des graphes
titles = (
    "SVC with linear kernel",
    "LinearSVC (linear kernel)",
    "SVC with RBF kernel",
    "SVC with polynomial (degree 3) kernel",
)
# Out:
# Fitting 5 folds for each of 16 candidates, totalling 80 fits
# [CV 1/5] END ....................C=0.1, gamma=1;, score=0.792 total time=   0.0s
# [CV 2/5] END ....................C=0.1, gamma=1;, score=0.750 total time=   0.0s
# [CV 3/5] END ....................C=0.1, gamma=1;, score=0.833 total time=   0.0s
# [CV 4/5] END ....................C=0.1, gamma=1;, score=0.917 total time=   0.0s
# [CV 5/5] END ....................C=0.1, gamma=1;, score=0.667 total time=   0.0s
# [CV 1/5] END ..................C=0.1, gamma=0.1;, score=0.625 total time=   0.0s
# [CV 2/5] END ..................C=0.1, gamma=0.1;, score=0.500 total time=   0.0s
# [CV 3/5] END ..................C=0.1, gamma=0.1;, score=0.583 total time=   0.0s
# [CV 4/5] END ..................C=0.1, gamma=0.1;, score=0.667 total time=   0.0s
# [CV 5/5] END ..................C=0.1, gamma=0.1;, score=0.583 total time=   0.0s
# [CV 1/5] END ..................C=0.1, gamma=0.7;, score=0.792 total time=   0.0s
# [CV 2/5] END ..................C=0.1, gamma=0.7;, score=0.708 total time=   0.0s
# [CV 3/5] END ..................C=0.1, gamma=0.7;, score=0.833 total time=   0.0s
# [CV 4/5] END ..................C=0.1, gamma=0.7;, score=0.958 total time=   0.0s
# [CV 5/5] END ..................C=0.1, gamma=0.7;, score=0.667 total time=   0.0s
# [CV 1/5] END .................C=0.1, gamma=0.01;, score=0.375 total time=   0.0s
# [CV 2/5] END .................C=0.1, gamma=0.01;, score=0.375 total time=   0.0s
# [CV 3/5] END .................C=0.1, gamma=0.01;, score=0.333 total time=   0.0s
# [CV 4/5] END .................C=0.1, gamma=0.01;, score=0.333 total time=   0.0s
# [CV 5/5] END .................C=0.1, gamma=0.01;, score=0.333 total time=   0.0s
# [CV 1/5] END ......................C=1, gamma=1;, score=0.708 total time=   0.0s
# [CV 2/5] END ......................C=1, gamma=1;, score=0.750 total time=   0.0s
# [CV 3/5] END ......................C=1, gamma=1;, score=0.833 total time=   0.0s
# [CV 4/5] END ......................C=1, gamma=1;, score=0.875 total time=   0.1s
# [CV 5/5] END ......................C=1, gamma=1;, score=0.625 total time=   0.0s
# [CV 1/5] END ....................C=1, gamma=0.1;, score=0.708 total time=   0.0s
# [CV 2/5] END ....................C=1, gamma=0.1;, score=0.750 total time=   0.0s
# [CV 3/5] END ....................C=1, gamma=0.1;, score=0.833 total time=   0.0s
# [CV 4/5] END ....................C=1, gamma=0.1;, score=0.958 total time=   0.0s
# [CV 5/5] END ....................C=1, gamma=0.1;, score=0.667 total time=   0.0s
# [CV 1/5] END ....................C=1, gamma=0.7;, score=0.708 total time=   0.0s
# [CV 2/5] END ....................C=1, gamma=0.7;, score=0.750 total time=   0.0s
# [CV 3/5] END ....................C=1, gamma=0.7;, score=0.833 total time=   0.0s
# [CV 4/5] END ....................C=1, gamma=0.7;, score=0.917 total time=   0.0s
# [CV 5/5] END ....................C=1, gamma=0.7;, score=0.625 total time=   0.0s
# [CV 1/5] END ...................C=1, gamma=0.01;, score=0.667 total time=   0.0s
# [CV 2/5] END ...................C=1, gamma=0.01;, score=0.500 total time=   0.0s
# [CV 3/5] END ...................C=1, gamma=0.01;, score=0.625 total time=   0.0s
# [CV 4/5] END ...................C=1, gamma=0.01;, score=0.792 total time=   0.0s
# [CV 5/5] END ...................C=1, gamma=0.01;, score=0.625 total time=   0.1s
# [CV 1/5] END ......................C=3, gamma=1;, score=0.750 total time=   0.0s
# [CV 2/5] END ......................C=3, gamma=1;, score=0.750 total time=   0.0s
# [CV 3/5] END ......................C=3, gamma=1;, score=0.792 total time=   0.0s
# [CV 4/5] END ......................C=3, gamma=1;, score=0.833 total time=   0.0s
# [CV 5/5] END ......................C=3, gamma=1;, score=0.625 total time=   0.0s
# [CV 1/5] END ....................C=3, gamma=0.1;, score=0.750 total time=   0.0s
# [CV 2/5] END ....................C=3, gamma=0.1;, score=0.750 total time=   0.0s
# [CV 3/5] END ....................C=3, gamma=0.1;, score=0.833 total time=   0.0s
# [CV 4/5] END ....................C=3, gamma=0.1;, score=0.917 total time=   0.0s
# [CV 5/5] END ....................C=3, gamma=0.1;, score=0.667 total time=   0.0s
# [CV 1/5] END ....................C=3, gamma=0.7;, score=0.708 total time=   0.0s
# [CV 2/5] END ....................C=3, gamma=0.7;, score=0.750 total time=   0.0s
# [CV 3/5] END ....................C=3, gamma=0.7;, score=0.792 total time=   0.0s
# [CV 4/5] END ....................C=3, gamma=0.7;, score=0.875 total time=   0.0s
# [CV 5/5] END ....................C=3, gamma=0.7;, score=0.625 total time=   0.0s
# [CV 1/5] END ...................C=3, gamma=0.01;, score=0.750 total time=   0.0s
# [CV 2/5] END ...................C=3, gamma=0.01;, score=0.625 total time=   0.0s
# [CV 3/5] END ...................C=3, gamma=0.01;, score=0.792 total time=   0.0s
# [CV 4/5] END ...................C=3, gamma=0.01;, score=0.958 total time=   0.0s
# [CV 5/5] END ...................C=3, gamma=0.01;, score=0.708 total time=   0.0s
# [CV 1/5] END .....................C=10, gamma=1;, score=0.750 total time=   0.0s
# [CV 2/5] END .....................C=10, gamma=1;, score=0.750 total time=   0.0s
# [CV 3/5] END .....................C=10, gamma=1;, score=0.792 total time=   0.0s
# [CV 4/5] END .....................C=10, gamma=1;, score=0.833 total time=   0.0s
# [CV 5/5] END .....................C=10, gamma=1;, score=0.625 total time=   0.0s
# [CV 1/5] END ...................C=10, gamma=0.1;, score=0.750 total time=   0.0s
# [CV 2/5] END ...................C=10, gamma=0.1;, score=0.750 total time=   0.0s
# [CV 3/5] END ...................C=10, gamma=0.1;, score=0.792 total time=   0.0s
# [CV 4/5] END ...................C=10, gamma=0.1;, score=0.917 total time=   0.0s
# [CV 5/5] END ...................C=10, gamma=0.1;, score=0.667 total time=   0.0s
# [CV 1/5] END ...................C=10, gamma=0.7;, score=0.750 total time=   0.0s
# [CV 2/5] END ...................C=10, gamma=0.7;, score=0.750 total time=   0.0s
# [CV 3/5] END ...................C=10, gamma=0.7;, score=0.792 total time=   0.0s
# [CV 4/5] END ...................C=10, gamma=0.7;, score=0.833 total time=   0.0s
# [CV 5/5] END ...................C=10, gamma=0.7;, score=0.625 total time=   0.0s
# [CV 1/5] END ..................C=10, gamma=0.01;, score=0.708 total time=   0.0s
# [CV 2/5] END ..................C=10, gamma=0.01;, score=0.750 total time=   0.0s
# [CV 3/5] END ..................C=10, gamma=0.01;, score=0.833 total time=   0.0s
# [CV 4/5] END ..................C=10, gamma=0.01;, score=0.958 total time=   0.0s
# [CV 5/5] END ..................C=10, gamma=0.01;, score=0.667 total time=   0.0s
# GridSearchCV(estimator=SVC(),
#              param_grid={'C': [0.1, 1, 3, 10], 'gamma': [1, 0.1, 0.7, 0.01]},
#              verbose=3)

# %%
for clf in models:
    clf.fit(X_train, Y_train)
    yhat= clf.predict(X_test)
    print(" -Implementation", clf)
    print("Valeur predite:")
    print(yhat[:])
    print("Ce qui est attendu:\n",Y_test)

    print("Les métriques", clf)
    mse = mean_squared_error(Y_test, yhat)
    score = clf.score(X_train, Y_train)
    if(choice==1):
        acc = accuracy_score(Y_test, yhat)
        print("Accuracy_score ", acc)

        print("Matice de confusion")
        matrix =confusion_matrix(Y_test, yhat)
        plt.figure()
        disp = ConfusionMatrixDisplay(confusion_matrix=matrix, display_labels=clf.classes_) 
        disp.plot()       
        # sns.heatmap(matrix, annot= True)

        print("classification_report")
        classification=classification_report(Y_test, yhat)
        print(classification)

    print('Le MSE (mean square error) value is: ', mse)
    print("Le score est: ", score)
    print("\n\n")
# Out:
#  -Implementation SVC(C=0.1, kernel='linear')
# Valeur predite:
# [1 1 1 0 2 1 0 1 0 1 1 1 2 2 0 0 1 2 0 0 1 1 0 1 1 2 2 1 1 1]
# Ce qui est attendu:
#  [1 2 2 0 2 1 0 1 0 1 1 2 2 2 0 0 2 2 0 0 1 2 0 1 1 2 1 1 1 2]
# Les métriques SVC(C=0.1, kernel='linear')
# Accuracy_score  0.7666666666666667
# Matice de confusion
# classification_report
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00         8
#            1       0.62      0.91      0.74        11
#            2       0.83      0.45      0.59        11
#
#     accuracy                           0.77        30
#    macro avg       0.82      0.79      0.78        30
# weighted avg       0.80      0.77      0.75        30
#
# Le MSE (mean square error) value is:  0.23333333333333334
# Le score est:  0.8
#
#
#
#  -Implementation LinearSVC(C=0.1, max_iter=100000)
# Valeur predite:
# [2 2 2 0 2 1 0 0 0 0 0 2 2 2 0 0 2 2 0 0 2 2 0 2 0 0 2 2 2 2]
# Ce qui est attendu:
#  [1 2 2 0 2 1 0 1 0 1 1 2 2 2 0 0 2 2 0 0 1 2 0 1 1 2 1 1 1 2]
# Les métriques LinearSVC(C=0.1, max_iter=100000)
# Accuracy_score  0.6333333333333333
# Matice de confusion
# classification_report
#               precision    recall  f1-score   support
#
#            0       0.62      1.00      0.76         8
#            1       1.00      0.09      0.17        11
#            2       0.62      0.91      0.74        11
#
#     accuracy                           0.63        30
#    macro avg       0.75      0.67      0.56        30
# weighted avg       0.76      0.63      0.54        30
#
# Le MSE (mean square error) value is:  0.4666666666666667
# Le score est:  0.75
#
#
#
#  -Implementation SVC(C=0.1, gamma=0.7)
# Valeur predite:
# [1 1 1 0 2 1 0 1 0 1 1 1 2 2 0 0 1 2 0 0 1 2 0 1 1 2 2 1 1 2]
# Ce qui est attendu:
#  [1 2 2 0 2 1 0 1 0 1 1 2 2 2 0 0 2 2 0 0 1 2 0 1 1 2 1 1 1 2]
# Les métriques SVC(C=0.1, gamma=0.7)
# Accuracy_score  0.8333333333333334
# Matice de confusion
# classification_report
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00         8
#            1       0.71      0.91      0.80        11
#            2       0.88      0.64      0.74        11
#
#     accuracy                           0.83        30
#    macro avg       0.86      0.85      0.85        30
# weighted avg       0.85      0.83      0.83        30
#
# Le MSE (mean square error) value is:  0.16666666666666666
# Le score est:  0.8166666666666667
#
#
#
#  -Implementation SVC(C=0.1, gamma=0.7, kernel='poly')
# Valeur predite:
# [1 1 1 0 2 1 0 1 0 1 1 1 2 2 0 0 1 2 0 0 1 1 0 1 1 2 2 1 1 1]
# Ce qui est attendu:
#  [1 2 2 0 2 1 0 1 0 1 1 2 2 2 0 0 2 2 0 0 1 2 0 1 1 2 1 1 1 2]
# Les métriques SVC(C=0.1, gamma=0.7, kernel='poly')
# Accuracy_score  0.7666666666666667
# Matice de confusion
# classification_report
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00         8
#            1       0.62      0.91      0.74        11
#            2       0.83      0.45      0.59        11
#
#     accuracy                           0.77        30
#    macro avg       0.82      0.79      0.78        30
# weighted avg       0.80      0.77      0.75        30
#
# Le MSE (mean square error) value is:  0.23333333333333334
# Le score est:  0.7833333333333333

# %%
# Regler la grille des graphe à 2x2  
fig, sub = plt.subplots(2, 2)
plt.subplots_adjust(wspace=0.4, hspace=0.4)

X0, X1 = X[:, 0], X[:, 1]

for clf, title, ax in zip(models, titles, sub.flatten()):
    disp = DecisionBoundaryDisplay.from_estimator(
        clf,
        X,
        response_method="predict",
        cmap=plt.cm.coolwarm,
        alpha=0.8,
        ax=ax,
        xlabel=iris.feature_names[0],
        ylabel=iris.feature_names[1],
    )
    ax.scatter(X0, X1, c=y, cmap=plt.cm.coolwarm, s=20, edgecolors="k")
    ax.set_xticks(())
    ax.set_yticks(())
    ax.set_title(title)

plt.show()
